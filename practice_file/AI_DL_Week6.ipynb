# %% [markdown]
# <a href="https://colab.research.google.com/github/HN-UI/25_1_AI_DL/blob/main/practice_file/AI_DL_Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
# 모델을 구성할 때 추가하고자 하는 layer를 add 해주는 방식도 있음
model = keras.Sequential()
# 두 layer 모두 output 차원
model.add(layers.Dense(64, activation="relu"))
model.add(layers.Dense(10, activation="softmax"))

# %%
# input dimension을 결정해주어야 model summary에서 output shape 결과와 parameter 개수가 나옴
model.build(input_shape=(None, 3))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.weights)
print(len(model.weights))
# Out:
# [<Variable path=sequential_1/dense_2/kernel, shape=(3, 64), dtype=float32, value=[[ 2.38019466e-01 -9.91670787e-02  2.37947941e-01  2.84798801e-01
#   -3.76206636e-03 -2.71778762e-01  2.85791457e-01 -6.86381459e-02
#    2.72891700e-01 -4.91932034e-03  3.12108696e-02  2.71475911e-01
#    7.50118494e-03  2.12782204e-01 -2.11648509e-01  2.81569898e-01
#   -7.79604763e-02  3.20790112e-02  2.65885830e-01  3.38269472e-02
#   -2.86925763e-01 -1.00981370e-01  2.89182663e-02  2.18845248e-01
#    1.10119343e-01  1.37465596e-01  1.92301303e-01  2.03389764e-01
#    7.07555413e-02  1.35162771e-02 -1.99547201e-01  2.72311807e-01
#    7.50759840e-02 -7.31852651e-03  1.20764434e-01  9.97369289e-02
#    2.95782626e-01  2.95237064e-01 -1.59397215e-01  9.07301009e-02
#   -2.75774300e-01 -2.33175308e-01  1.58194959e-01  1.45935893e-01
#    2.51499832e-01 -1.42731965e-02  2.85765886e-01 -1.60212502e-01
#    2.13644803e-02 -1.77703112e-01  2.17498660e-01  2.69332767e-01
# ...

# %%
model.weights[0].shape
# Out:
# TensorShape([3, 64])

# %%
model.weights[1].shape
# Out:
# TensorShape([64])

# %%
model = keras.Sequential(name="my_example_model")
model.add(layers.Dense(64, activation="relu", name="my_first_layer"))
model.add(layers.Dense(10, activation="softmax", name="my_last_layer"))
model.build((None, 3))
model.summary()
# Out:
# Model: "my_example_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ my_first_layer (Dense)          │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ my_last_layer (Dense)           │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential()
# input dimension add로 추가
model.add(keras.Input(shape=(3,)))
model.add(layers.Dense(64, activation="relu"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           256 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 256 (1.00 KB)
#  Trainable params: 256 (1.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 추가로 add 해줄 수도 있음
model.add(layers.Dense(10, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---

# %%
inputs = keras.Input(shape=(3,), name="my_input")
features = layers.Dense(64, activation="relu")(inputs)
outputs = layers.Dense(10, activation="softmax")(features)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
inputs = keras.Input(shape=(3,), name="my_input")

# %%
inputs.shape
# Out:
# (None, 3)

# %%
inputs.dtype
# Out:
# 'float32'

# %%
features = layers.Dense(64, activation="relu")(inputs)

# %%
features.shape
# Out:
# (None, 64)

# %%
outputs = layers.Dense(10, activation="softmax")(features)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ my_input (InputLayer)           │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---
# ### multi-input, multi-output

# %%
# one-hot encoding을 위한 차원
vocabulary_size = 10000
num_tags = 100
num_departments = 4

title = keras.Input(shape=(vocabulary_size,), name="title")
text_body = keras.Input(shape=(vocabulary_size,), name="text_body")
tags = keras.Input(shape=(num_tags,), name="tags")

# feature를 결합하여 하나의 입력으로 만듦 (input이 들어갈 자리)
features = layers.Concatenate()([title, text_body, tags])
features = layers.Dense(64, activation="relu")(features)

# sigmoid 통과 시 output={0, 1} 이므로 차원 1로 설정
priority = layers.Dense(1, activation="sigmoid", name="priority")(features)
# softmax 통과 시 class 수(num_departements)만큼의 확률 값 return하므로 차원 그에 맞게 설명
department = layers.Dense(
    num_departments, activation="softmax", name="department")(features)

# input, output 명시
model = keras.Model(inputs=[title, text_body, tags], outputs=[priority, department])

# %%
model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ title (InputLayer)        │ (None, 10000)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_body (InputLayer)    │ (None, 10000)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ tags (InputLayer)         │ (None, 100)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
keras.utils.plot_model(model, "ticket_classifier.png")

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
vocabulary_size = 10000
num_tags = 100
num_department = 4

title = keras.Input(shape = (vocabulary_size,), name = "title")
text_body = keras.Input(shape = (vocabulary_size, ), name = "text_body")
tags = keras.Input(shape = (num_tags, ), name = "tags")

features = layers.Concatenate()([title, text_body, tags])
features = layers.Dense(64, activation = "relu")(features)
features = layers.Dense(36, activation = "relu")(features)
features = layers.Dense(24, activation = "relu")(features)

priority = layers.Dense(1, activation = "sigmoid", name = "priority")(features)
department = layers.Dense(num_department, activation = "softmax", name = "department")(features)

model1 = keras.Model(inputs=[title, text_body, tags], outputs=[priority, department])
keras.utils.plot_model(model1, show_shapes=True)

# %%
title = keras.Input(shape = (vocabulary_size, ), name = "title")
text_body = keras.Input(shape = (vocabulary_size, ), name = "text_body")
tags = keras.Input(shape = (num_tags, ), name = "tags")

features = layers.Concatenate()([title, text_body, tags])
features = layers.Dense(64, activation = "relu")(features)
features = layers.Dense(36, activation = "relu")(features)
features_sep1 = layers.Dense(24, activation = "relu")(features)
difficulty = layers.Dense(3, activation = "softmax", name = "difficulty")(features)

priority = layers.Dense(1, activation = "sigmoid", name = "priority")(features_sep1)
department = layers.Dense(num_department, activation = "softmax", name = "department")(features_sep1)

model2 = keras.Model(inputs = [title, text_body, tags], outputs = [difficulty, department, priority])
keras.utils.plot_model(model2, show_shapes = True)

# %%
import numpy as np

num_samples = 1280

# fake data 생성
title_data = np.random.randint(0, 2, size=(num_samples, vocabulary_size))
text_body_data = np.random.randint(0, 2, size=(num_samples, vocabulary_size))
tags_data = np.random.randint(0, 2, size=(num_samples, num_tags))

priority_data = np.random.random(size=(num_samples, 1))
department_data = np.random.randint(0, 2, size=(num_samples, num_departments))

model.compile(optimizer="rmsprop",
              # 각각 다른 output에 대해 다른 loss와 다른 metric을 사용
              loss=["mean_squared_error", "categorical_crossentropy"],
              metrics=[["mean_absolute_error"], ["accuracy"]])
model.fit([title_data, text_body_data, tags_data],
          [priority_data, department_data],
          epochs=5)
model.evaluate([title_data, text_body_data, tags_data],
               [priority_data, department_data])
priority_preds, department_preds = model.predict([title_data, text_body_data, tags_data])
# Out:
# Epoch 1/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - department_accuracy: 0.2785 - department_loss: 87.4823 - loss: 87.8107 - priority_loss: 0.3284 - priority_mean_absolute_error: 0.4987
# Epoch 2/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - department_accuracy: 0.2348 - department_loss: 74.9139 - loss: 75.2465 - priority_loss: 0.3326 - priority_mean_absolute_error: 0.5013
# Epoch 3/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - department_accuracy: 0.2394 - department_loss: 76.7934 - loss: 77.1272 - priority_loss: 0.3338 - priority_mean_absolute_error: 0.5017
# Epoch 4/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - department_accuracy: 0.2512 - department_loss: 89.2569 - loss: 89.5801 - priority_loss: 0.3232 - priority_mean_absolute_error: 0.4933
# Epoch 5/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - department_accuracy: 0.2778 - department_loss: 94.5872 - loss: 94.9257 - priority_loss: 0.3385 - priority_mean_absolute_error: 0.5088
# ...

# %%
model.compile(optimizer="rmsprop",
              # 딕셔너리로 어떤 key에 어떤 loss function과 metric을 사용할 것 인지 model에 정의
              loss={
                  "priority": "mean_squared_error",
                  "department": "categorical_crossentropy"
                  },
              metrics={
                  "priority": ["mean_absolute_error"],
                  "department": ["accuracy"]
                  }
              )

model.fit(
    {
        #input의 key 값 명시
        "title": title_data,
        "text_body": text_body_data,
        "tags": tags_data
    },
    {
        # output의 key 값 명시
        "priority": priority_data,
        "department": department_data
    },

    epochs=20
)
# 딕셔너리 설정에 맞게 input 집어넣기
model.evaluate({"title": title_data, "text_body": text_body_data, "tags": tags_data},
               {"priority": priority_data, "department": department_data})
priority_preds, department_preds = model.predict(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data})
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - department_accuracy: 0.2412 - department_loss: 154.0503 - loss: 154.3866 - priority_loss: 0.3364 - priority_mean_absolute_error: 0.5041
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - department_accuracy: 0.2368 - department_loss: 115.1771 - loss: 115.5114 - priority_loss: 0.3343 - priority_mean_absolute_error: 0.5028
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - department_accuracy: 0.2575 - department_loss: 127.9682 - loss: 128.2941 - priority_loss: 0.3259 - priority_mean_absolute_error: 0.4946
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - department_accuracy: 0.2256 - department_loss: 137.7637 - loss: 138.0852 - priority_loss: 0.3215 - priority_mean_absolute_error: 0.4916
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - department_accuracy: 0.2580 - department_loss: 140.9928 - loss: 141.3232 - priority_loss: 0.3303 - priority_mean_absolute_error: 0.4997
# Epoch 6/20
# ...

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model.layers
# Out:
# [<InputLayer name=title, built=True>,
#  <InputLayer name=text_body, built=True>,
#  <InputLayer name=tags, built=True>,
#  <Concatenate name=concatenate, built=True>,
#  <Dense name=dense_11, built=True>,
#  <Dense name=priority, built=True>,
#  <Dense name=department, built=True>]

# %%
model.layers[3].input
# Out:
# [<KerasTensor shape=(None, 10000), dtype=float32, sparse=False, name=title>,
#  <KerasTensor shape=(None, 10000), dtype=float32, sparse=False, name=text_body>,
#  <KerasTensor shape=(None, 100), dtype=float32, sparse=False, name=tags>]

# %%
model.layers[3].output
# Out:
# <KerasTensor shape=(None, 20100), dtype=float32, sparse=False, name=keras_tensor_22>

# %%
features = model.layers[4].output
# output layer 추가
difficulty = layers.Dense(3, activation="softmax", name="difficulty")(features)

new_model = keras.Model(
    inputs=[title, text_body, tags],
    outputs=[priority, department, difficulty])

# %%
keras.utils.plot_model(new_model, "updated_ticket_classifier.png", show_shapes=True)

# %%
# 직접 해보기
model.compile(optimizer="rmsprop",
              loss = {
                  "priority": "mean_squared_error",
                  "department": "categorical_crossentropy"
              },
              metrics = {
                  "priority": ["mean_absolute_error"],
                  "department": ["accuracy"]
              }
)
model.fit()

# %% [markdown]
# ---
# ### Subclassed model

# %%
class CustomerTicketModel(keras.Model):

    def __init__(self, num_departments):
        super().__init__()
        self.concat_layer = layers.Concatenate()
        self.mixing_layer = layers.Dense(64, activation="relu")
        self.priority_scorer = layers.Dense(1, activation="sigmoid")
        self.department_classifier = layers.Dense(
            num_departments, activation="softmax")

    def call(self, inputs):
        # key 값으로 input 데이터 불러오기
        title = inputs["title"]
        text_body = inputs["text_body"]
        tags = inputs["tags"]

        # input concatenation
        features = self.concat_layer([title, text_body, tags])
        #
        features = self.mixing_layer(features)
        priority = self.priority_scorer(features)
        department = self.department_classifier(features)
        return priority, department

# %%
model = CustomerTicketModel(num_departments=4)

priority, department = model(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data})

# %%
model.summary()
# Out:
# Model: "customer_ticket_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ concatenate_1 (Concatenate)          │ (1280, 20100)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (1280, 64)                  │       1,286,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (1280, 1)                   │              65 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (1280, 4)                   │             260 │
# ...

# %%
class Classifier(keras.Model):

    def __init__(self, num_classes=2):
        super().__init__()
        # class 개수에 따라 각각 다른 활성화 함수 사용
        if num_classes == 2:
            num_units = 1
            activation = "sigmoid"
        else:
            num_units = num_classes
            activation = "softmax"
        self.dense = layers.Dense(num_units, activation=activation)

    def call(self, inputs):
        return self.dense(inputs)

inputs = keras.Input(shape=(3,))
features = layers.Dense(64, activation="relu")(inputs)
outputs = Classifier(num_classes=10)(features)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
inputs = keras.Input(shape=(64,))
outputs = layers.Dense(1, activation="sigmoid")(inputs)
binary_classifier = keras.Model(inputs=inputs, outputs=outputs)

class MyModel(keras.Model):

    def __init__(self, num_classes=2):
        super().__init__()
        self.dense = layers.Dense(64, activation="relu")
        self.classifier = binary_classifier

    def call(self, inputs):
        features = self.dense(inputs)
        return self.classifier(features)

model = MyModel()

# %%
from tensorflow.keras.datasets import mnist

# functional api를 사용하여 모델 불러오기
def get_mnist_model():
    inputs = keras.Input(shape=(28 * 28,))
    features = layers.Dense(512, activation="relu")(inputs)
    features = layers.Dropout(0.5)(features)
    outputs = layers.Dense(10, activation="softmax")(features)
    model = keras.Model(inputs, outputs)
    return model

# mnist 데이터 불러오기
(images, labels), (test_images, test_labels) = mnist.load_data()
images = images.reshape((60000, 28 * 28)).astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28)).astype("float32") / 255

# train과 validation set 구분하기
train_images, val_images = images[10000:], images[:10000]
train_labels, val_labels = labels[10000:], labels[:10000]

model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
predictions = model.predict(test_images)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8657 - loss: 0.4457 - val_accuracy: 0.9539 - val_loss: 0.1571
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9502 - loss: 0.1690 - val_accuracy: 0.9682 - val_loss: 0.1189
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9618 - loss: 0.1327 - val_accuracy: 0.9712 - val_loss: 0.1080
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9680 - loss: 0.1130
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from keras import ops
class RootMeanSquaredError(keras.metrics.Metric): #1
  def __init__(self, name="rmse", **kwargs): #2
    super().__init__(name=name, **kwargs) #2
    self.mse_sum = self.add_weight(name="mse_sum", initializer="zeros") #2
    self.total_samples = self.add_weight( #2
      name="total_samples", initializer="zeros") #2

  def update_state(self, y_true, y_pred, sample_weight=None): #3
    y_true = ops.one_hot(y_true, num_classes=ops.shape(y_pred)[1]) #3
    mse = ops.sum(ops.square(y_true - y_pred)) #3
    self.mse_sum.assign_add(mse) #3
    num_samples = ops.shape(y_pred)[0] #3
    self.total_samples.assign_add(num_samples) #3

  def result(self):
    return ops.sqrt(self.mse_sum / self.total_samples)

  def reset_state(self):
    self.mse_sum.assign(0.)
    self.total_samples.assign(0)

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy", RootMeanSquaredError()])
# cpu로 돌리면 됨 (버전 달라서 오류 발생)
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8675 - loss: 0.4513 - rmse: 0.4376 - val_accuracy: 0.9535 - val_loss: 0.1653 - val_rmse: 0.2668
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9521 - loss: 0.1605 - rmse: 0.2681 - val_accuracy: 0.9707 - val_loss: 0.1116 - val_rmse: 0.2153
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9630 - loss: 0.1296 - rmse: 0.2388 - val_accuracy: 0.9741 - val_loss: 0.0999 - val_rmse: 0.2040
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9694 - loss: 0.1079 - rmse: 0.2157

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
