# %% [markdown]
# <a href="https://colab.research.google.com/github/HN-UI/25_1_AI_DL/blob/main/practice_file/AI_DL_Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import mnist
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
def get_mnist_model():
    inputs = keras.Input(shape=(28 * 28,))
    features = layers.Dense(512, activation="relu")(inputs)
    features = layers.Dropout(0.5)(features)
    outputs = layers.Dense(10, activation="softmax")(features)
    model = keras.Model(inputs, outputs)
    return model

(images, labels), (test_images, test_labels) = mnist.load_data()
images = images.reshape((60000, 28 * 28)).astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28)).astype("float32") / 255
train_images, val_images = images[10000:], images[:10000]
train_labels, val_labels = labels[10000:], labels[:10000]

model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
predictions = model.predict(test_images)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8684 - loss: 0.4426 - val_accuracy: 0.9508 - val_loss: 0.1580
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9512 - loss: 0.1649 - val_accuracy: 0.9677 - val_loss: 0.1138
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9627 - loss: 0.1317 - val_accuracy: 0.9700 - val_loss: 0.1058
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9707 - loss: 0.1170
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from keras import ops
class RootMeanSquaredError(keras.metrics.Metric): #1
  def __init__(self, name="rmse", **kwargs): #2
    super().__init__(name=name, **kwargs) #2
    self.mse_sum = self.add_weight(name="mse_sum", initializer="zeros") #2
    self.total_samples = self.add_weight( #2
      name="total_samples", initializer="zeros") #2

  def update_state(self, y_true, y_pred, sample_weight=None): #3
    y_true = ops.one_hot(y_true, num_classes=ops.shape(y_pred)[1]) #3
    mse = ops.sum(ops.square(y_true - y_pred)) #3
    self.mse_sum.assign_add(mse) #3
    num_samples = ops.shape(y_pred)[0] #3
    self.total_samples.assign_add(num_samples) #3

  def result(self):
    return ops.sqrt(self.mse_sum / self.total_samples)

  def reset_state(self):
    self.mse_sum.assign(0.)
    self.total_samples.assign(0)

# %%
m = RootMeanSquaredError()
m.update_state(np.array([0, 1]), np.array([[0.05, 0.95, 0], [0.1, 0.8, 0.1]]))
m.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.9656603336334229>

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy", RootMeanSquaredError()])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8653 - loss: 0.4404 - rmse: 0.4361 - val_accuracy: 0.9589 - val_loss: 0.1424 - val_rmse: 0.2498
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.9517 - loss: 0.1656 - rmse: 0.2711 - val_accuracy: 0.9662 - val_loss: 0.1198 - val_rmse: 0.2262
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9637 - loss: 0.1321 - rmse: 0.2394 - val_accuracy: 0.9682 - val_loss: 0.1136 - val_rmse: 0.2209
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9663 - loss: 0.1251 - rmse: 0.2272

# %%
model = get_mnist_model()
model.compile(optimizer=keras.optimizers.RMSprop(),
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=[keras.metrics.SparseCategoricalAccuracy(), RootMeanSquaredError()])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.4494 - rmse: 0.4399 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.1427 - val_rmse: 0.2506 - val_sparse_categorical_accuracy: 0.9593
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.1630 - rmse: 0.2687 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1201 - val_rmse: 0.2243 - val_sparse_categorical_accuracy: 0.9671
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1326 - rmse: 0.2410 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.1026 - val_rmse: 0.2067 - val_sparse_categorical_accuracy: 0.9722
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1059 - rmse: 0.2152 - sparse_categorical_accuracy: 0.9687

# %%
m = RootMeanSquaredError()
m.update_state(np.array([1, 1]), np.array([[0.05, 0.95, 0], [0.1, 0.8, 0.1]]))
m.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.18027755618095398>

# %%
m = keras.metrics.SparseCategoricalCrossentropy()
m.update_state(np.array([1, 1]), np.array([[0.05, 0.95, 0], [0.1, 0.8, 0.1]]))
m.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.13721847534179688>

# %%
m.update_state(train_labels[:5], model.predict(train_images[:5]))
m.result()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# <tf.Tensor: shape=(), dtype=float32, numpy=0.05104357376694679>

# %%
m = keras.metrics.SparseCategoricalAccuracy()
m.update_state(train_labels[:5], model.predict(train_images[:5]))
m.result()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0>

# %% [markdown]
# ---

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        # 2 epoch 연속으로 val_accuracy 향상이 없으면 종료하겠다
        patience=2,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath="checkpoint_path.keras",
        monitor="val_loss",
        # val_loss가 가장 낮은 순간의 모델을 저장한다
        save_best_only=True,
    )
]
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          # callback list 전달, 학습 도중에 earlystopping과 checkpoint가 작동하도록 함
          callbacks=callbacks_list,
          validation_data=(val_images, val_labels))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8630 - loss: 0.4551 - val_accuracy: 0.9565 - val_loss: 0.1480
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9526 - loss: 0.1641 - val_accuracy: 0.9666 - val_loss: 0.1228
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9633 - loss: 0.1298 - val_accuracy: 0.9734 - val_loss: 0.1001
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9676 - loss: 0.1147 - val_accuracy: 0.9748 - val_loss: 0.1077
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9728 - loss: 0.1006 - val_accuracy: 0.9739 - val_loss: 0.1036
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9737 - loss: 0.0966 - val_accuracy: 0.9760 - val_loss: 0.1017
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9758 - loss: 0.0919 - val_accuracy: 0.9770 - val_loss: 0.0936
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9783 - loss: 0.0798 - val_accuracy: 0.9809 - val_loss: 0.0923
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9800 - loss: 0.0724 - val_accuracy: 0.9783 - val_loss: 0.0951
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9808 - loss: 0.0707 - val_accuracy: 0.9814 - val_loss: 0.0879

# %%
model = keras.models.load_model("checkpoint_path.keras")

# %%
from matplotlib import pyplot as plt

class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs):
        self.per_batch_losses = []

    def on_batch_end(self, batch, logs):
        self.per_batch_losses.append(logs.get("loss"))

    def on_epoch_end(self, epoch, logs):
        plt.clf()
        plt.plot(range(len(self.per_batch_losses)), self.per_batch_losses,
                 label="Training loss for each batch")
        plt.xlabel(f"Batch (epoch {epoch})")
        plt.ylabel("Loss")
        plt.legend()
        plt.savefig(f"plot_at_epoch_{epoch}")
        self.per_batch_losses = []

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          callbacks=[LossHistory()],
          validation_data=(val_images, val_labels))
# (텐서보드 스킵)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8600 - loss: 0.4607 - val_accuracy: 0.9515 - val_loss: 0.1621
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9469 - loss: 0.1716 - val_accuracy: 0.9667 - val_loss: 0.1233
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9630 - loss: 0.1290 - val_accuracy: 0.9721 - val_loss: 0.1053
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9674 - loss: 0.1132 - val_accuracy: 0.9741 - val_loss: 0.0975
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9701 - loss: 0.1058 - val_accuracy: 0.9757 - val_loss: 0.0955
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9728 - loss: 0.0978 - val_accuracy: 0.9769 - val_loss: 0.0952
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9768 - loss: 0.0825 - val_accuracy: 0.9786 - val_loss: 0.0863
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9776 - loss: 0.0816 - val_accuracy: 0.9773 - val_loss: 0.0949
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9783 - loss: 0.0757 - val_accuracy: 0.9783 - val_loss: 0.1050
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9817 - loss: 0.0686 - val_accuracy: 0.9807 - val_loss: 0.0893

# %% [markdown]
# ---

# %%
import tensorflow as tf
model = get_mnist_model()

loss_fn = keras.losses.SparseCategoricalCrossentropy()
optimizer = keras.optimizers.RMSprop()
metrics = [keras.metrics.SparseCategoricalAccuracy()]
loss_tracking_metric = keras.metrics.Mean()

# GPU에서 함수 실행 -> 빠르게 수행 가능
@tf.function
def train_step(inputs, targets):
    with tf.GradientTape() as tape:
        # training = True 해둬야함
        predictions = model(inputs, training=True)
        loss = loss_fn(targets, predictions)
    gradients = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(gradients, model.trainable_weights))

    logs = {}
    for metric in metrics:
        metric.update_state(targets, predictions)
        logs[metric.name] = metric.result()

    loss_tracking_metric.update_state(loss)
    logs["loss"] = loss_tracking_metric.result()
    return logs

# %%
def reset_metrics():
    for metric in metrics:
        metric.reset_state()
    loss_tracking_metric.reset_state()

# %%
training_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
training_dataset = training_dataset.batch(32)
epochs = 3
for epoch in range(epochs):
    reset_metrics()
    for inputs_batch, targets_batch in training_dataset:
        logs = train_step(inputs_batch, targets_batch)
    print(f"Results at the end of epoch {epoch}")
    for key, value in logs.items():
        print(f"...{key}: {value:.4f}")
# Out:
# Results at the end of epoch 0
# ...sparse_categorical_accuracy: 0.9135
# ...loss: 0.2923
# Results at the end of epoch 1
# ...sparse_categorical_accuracy: 0.9537
# ...loss: 0.1635
# Results at the end of epoch 2
# ...sparse_categorical_accuracy: 0.9638
# ...loss: 0.1305

# %%
training_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
training_dataset = training_dataset.batch(100)
epochs = 3
for epoch in range(epochs):
    reset_metrics()
    for inputs_batch, targets_batch in training_dataset:
        logs = train_step(inputs_batch, targets_batch)
        print(f"Results at this batch of epoch {epoch}")
        for key, value in logs.items():
            print(f"...{key}: {value:.4f}")
    print(f"Results at the end of epoch {epoch}")
    for key, value in logs.items():
        print(f"...{key}: {value:.4f}")
# Out:
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.1300
# ...loss: 2.4236
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.2650
# ...loss: 2.1429
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.3233
# ...loss: 1.9907
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.3925
# ...loss: 1.8368
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.4540
# ...loss: 1.7136
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.4933
# ...loss: 1.6219
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.5357
# ...loss: 1.5403
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.5462
# ...loss: 1.4829
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.5633
# ...loss: 1.4239
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.5850
# ...loss: 1.3661
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6082
# ...loss: 1.3028
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6208
# ...loss: 1.2652
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6323
# ...loss: 1.2332
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6393
# ...loss: 1.2070
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6527
# ...loss: 1.1716
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6581
# ...loss: 1.1527
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6659
# ...loss: 1.1296
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6694
# ...loss: 1.1149
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6732
# ...loss: 1.0980
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6790
# ...loss: 1.0789
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6852
# ...loss: 1.0557
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6941
# ...loss: 1.0327
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.6974
# ...loss: 1.0216
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7025
# ...loss: 1.0080
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7076
# ...loss: 0.9936
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7115
# ...loss: 0.9826
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7119
# ...loss: 0.9768
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7125
# ...loss: 0.9684
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7152
# ...loss: 0.9573
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7170
# ...loss: 0.9479
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7174
# ...loss: 0.9438
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7197
# ...loss: 0.9353
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7248
# ...loss: 0.9204
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7274
# ...loss: 0.9106
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7329
# ...loss: 0.8965
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7372
# ...loss: 0.8814
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7397
# ...loss: 0.8732
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7413
# ...loss: 0.8678
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7428
# ...loss: 0.8598
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7435
# ...loss: 0.8583
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7441
# ...loss: 0.8510
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7469
# ...loss: 0.8446
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7484
# ...loss: 0.8390
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7491
# ...loss: 0.8371
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7516
# ...loss: 0.8293
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7522
# ...loss: 0.8254
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7519
# ...loss: 0.8257
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7527
# ...loss: 0.8248
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7539
# ...loss: 0.8198
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7566
# ...loss: 0.8114
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7600
# ...loss: 0.8017
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7621
# ...loss: 0.7965
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7640
# ...loss: 0.7904
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7661
# ...loss: 0.7834
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7684
# ...loss: 0.7766
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7702
# ...loss: 0.7715
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7728
# ...loss: 0.7645
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7729
# ...loss: 0.7631
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7736
# ...loss: 0.7610
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7743
# ...loss: 0.7581
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7751
# ...loss: 0.7549
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7763
# ...loss: 0.7496
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7778
# ...loss: 0.7440
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7800
# ...loss: 0.7381
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7814
# ...loss: 0.7332
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7829
# ...loss: 0.7288
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7837
# ...loss: 0.7252
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7840
# ...loss: 0.7225
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7851
# ...loss: 0.7183
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7859
# ...loss: 0.7156
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7862
# ...loss: 0.7129
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7868
# ...loss: 0.7095
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7873
# ...loss: 0.7075
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7889
# ...loss: 0.7016
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7903
# ...loss: 0.6987
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7913
# ...loss: 0.6974
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7929
# ...loss: 0.6940
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7931
# ...loss: 0.6917
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7941
# ...loss: 0.6891
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7958
# ...loss: 0.6841
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7973
# ...loss: 0.6805
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.7990
# ...loss: 0.6752
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8000
# ...loss: 0.6715
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8014
# ...loss: 0.6667
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8018
# ...loss: 0.6650
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8030
# ...loss: 0.6613
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8043
# ...loss: 0.6572
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8057
# ...loss: 0.6535
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8066
# ...loss: 0.6503
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8079
# ...loss: 0.6461
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8086
# ...loss: 0.6444
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8098
# ...loss: 0.6412
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8104
# ...loss: 0.6393
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8110
# ...loss: 0.6377
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8117
# ...loss: 0.6341
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8122
# ...loss: 0.6326
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8136
# ...loss: 0.6285
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8150
# ...loss: 0.6241
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8157
# ...loss: 0.6220
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8159
# ...loss: 0.6199
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8162
# ...loss: 0.6189
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8170
# ...loss: 0.6177
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8179
# ...loss: 0.6152
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8191
# ...loss: 0.6119
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8200
# ...loss: 0.6082
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8205
# ...loss: 0.6061
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8212
# ...loss: 0.6037
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8217
# ...loss: 0.6030
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8220
# ...loss: 0.6013
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8219
# ...loss: 0.6011
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8227
# ...loss: 0.5991
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8233
# ...loss: 0.5972
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8244
# ...loss: 0.5942
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8250
# ...loss: 0.5924
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8257
# ...loss: 0.5895
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8264
# ...loss: 0.5872
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8271
# ...loss: 0.5848
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8281
# ...loss: 0.5817
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8292
# ...loss: 0.5783
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8299
# ...loss: 0.5761
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8309
# ...loss: 0.5730
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8311
# ...loss: 0.5717
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8316
# ...loss: 0.5708
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8325
# ...loss: 0.5680
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8326
# ...loss: 0.5672
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8320
# ...loss: 0.5686
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8323
# ...loss: 0.5674
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8328
# ...loss: 0.5654
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8334
# ...loss: 0.5630
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8344
# ...loss: 0.5598
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8347
# ...loss: 0.5584
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8352
# ...loss: 0.5573
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8361
# ...loss: 0.5544
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8366
# ...loss: 0.5525
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8374
# ...loss: 0.5503
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8377
# ...loss: 0.5486
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8379
# ...loss: 0.5475
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8381
# ...loss: 0.5465
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8382
# ...loss: 0.5457
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8386
# ...loss: 0.5447
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8390
# ...loss: 0.5432
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8398
# ...loss: 0.5410
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8398
# ...loss: 0.5405
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8404
# ...loss: 0.5383
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8408
# ...loss: 0.5369
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8414
# ...loss: 0.5355
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8416
# ...loss: 0.5347
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8418
# ...loss: 0.5343
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8421
# ...loss: 0.5327
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8426
# ...loss: 0.5318
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8432
# ...loss: 0.5299
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8439
# ...loss: 0.5280
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8443
# ...loss: 0.5264
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8446
# ...loss: 0.5251
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8453
# ...loss: 0.5230
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8458
# ...loss: 0.5214
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8467
# ...loss: 0.5193
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8472
# ...loss: 0.5176
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8477
# ...loss: 0.5161
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8478
# ...loss: 0.5150
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8483
# ...loss: 0.5132
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8489
# ...loss: 0.5115
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8494
# ...loss: 0.5100
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8498
# ...loss: 0.5092
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8502
# ...loss: 0.5079
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8505
# ...loss: 0.5072
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8508
# ...loss: 0.5068
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8508
# ...loss: 0.5065
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8510
# ...loss: 0.5063
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8516
# ...loss: 0.5045
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8519
# ...loss: 0.5029
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8519
# ...loss: 0.5031
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8522
# ...loss: 0.5021
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8526
# ...loss: 0.5008
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8528
# ...loss: 0.4996
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8532
# ...loss: 0.4983
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8534
# ...loss: 0.4976
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8538
# ...loss: 0.4964
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8542
# ...loss: 0.4950
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8547
# ...loss: 0.4932
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8553
# ...loss: 0.4913
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8555
# ...loss: 0.4906
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8560
# ...loss: 0.4894
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8562
# ...loss: 0.4892
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8568
# ...loss: 0.4880
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8572
# ...loss: 0.4870
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8573
# ...loss: 0.4869
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8574
# ...loss: 0.4859
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8578
# ...loss: 0.4844
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8581
# ...loss: 0.4830
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8585
# ...loss: 0.4819
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8586
# ...loss: 0.4817
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8589
# ...loss: 0.4809
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8590
# ...loss: 0.4802
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8592
# ...loss: 0.4793
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8595
# ...loss: 0.4780
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8599
# ...loss: 0.4769
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8601
# ...loss: 0.4766
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8602
# ...loss: 0.4762
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8601
# ...loss: 0.4760
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8601
# ...loss: 0.4756
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8602
# ...loss: 0.4752
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8606
# ...loss: 0.4741
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8609
# ...loss: 0.4729
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8609
# ...loss: 0.4724
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8611
# ...loss: 0.4714
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8612
# ...loss: 0.4712
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8614
# ...loss: 0.4702
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8614
# ...loss: 0.4698
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8618
# ...loss: 0.4688
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8620
# ...loss: 0.4681
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8620
# ...loss: 0.4687
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8621
# ...loss: 0.4680
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8620
# ...loss: 0.4682
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8621
# ...loss: 0.4675
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8626
# ...loss: 0.4664
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8627
# ...loss: 0.4660
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8627
# ...loss: 0.4662
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8629
# ...loss: 0.4653
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8631
# ...loss: 0.4647
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8632
# ...loss: 0.4639
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8632
# ...loss: 0.4634
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8633
# ...loss: 0.4629
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8631
# ...loss: 0.4627
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8631
# ...loss: 0.4625
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8635
# ...loss: 0.4614
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8637
# ...loss: 0.4607
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8641
# ...loss: 0.4601
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8643
# ...loss: 0.4594
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8648
# ...loss: 0.4582
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8650
# ...loss: 0.4574
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8654
# ...loss: 0.4562
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8657
# ...loss: 0.4554
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8658
# ...loss: 0.4551
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8661
# ...loss: 0.4542
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8663
# ...loss: 0.4533
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8667
# ...loss: 0.4521
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8671
# ...loss: 0.4514
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8674
# ...loss: 0.4499
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8679
# ...loss: 0.4485
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8682
# ...loss: 0.4476
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8686
# ...loss: 0.4465
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8690
# ...loss: 0.4452
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8693
# ...loss: 0.4442
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8694
# ...loss: 0.4439
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8693
# ...loss: 0.4439
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8693
# ...loss: 0.4438
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8693
# ...loss: 0.4433
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8694
# ...loss: 0.4431
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8695
# ...loss: 0.4424
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8698
# ...loss: 0.4414
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8700
# ...loss: 0.4407
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8701
# ...loss: 0.4401
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8704
# ...loss: 0.4390
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8705
# ...loss: 0.4388
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8708
# ...loss: 0.4376
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8710
# ...loss: 0.4369
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8713
# ...loss: 0.4359
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8717
# ...loss: 0.4347
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8718
# ...loss: 0.4340
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8720
# ...loss: 0.4334
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8723
# ...loss: 0.4328
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8725
# ...loss: 0.4319
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8727
# ...loss: 0.4310
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8727
# ...loss: 0.4307
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8729
# ...loss: 0.4298
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8733
# ...loss: 0.4286
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8735
# ...loss: 0.4279
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8737
# ...loss: 0.4273
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8740
# ...loss: 0.4263
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8742
# ...loss: 0.4259
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8743
# ...loss: 0.4257
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8743
# ...loss: 0.4253
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8742
# ...loss: 0.4259
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8741
# ...loss: 0.4260
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8741
# ...loss: 0.4259
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8743
# ...loss: 0.4251
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8745
# ...loss: 0.4246
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8747
# ...loss: 0.4240
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8749
# ...loss: 0.4235
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8752
# ...loss: 0.4227
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8755
# ...loss: 0.4217
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8757
# ...loss: 0.4210
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8757
# ...loss: 0.4205
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8760
# ...loss: 0.4195
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8760
# ...loss: 0.4195
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8761
# ...loss: 0.4189
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8763
# ...loss: 0.4184
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8766
# ...loss: 0.4173
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8769
# ...loss: 0.4166
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8771
# ...loss: 0.4158
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8774
# ...loss: 0.4152
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8775
# ...loss: 0.4145
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8774
# ...loss: 0.4148
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8775
# ...loss: 0.4149
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8776
# ...loss: 0.4143
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8777
# ...loss: 0.4141
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8779
# ...loss: 0.4135
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8780
# ...loss: 0.4131
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8781
# ...loss: 0.4129
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8783
# ...loss: 0.4122
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8785
# ...loss: 0.4114
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8788
# ...loss: 0.4106
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8788
# ...loss: 0.4102
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8790
# ...loss: 0.4098
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8792
# ...loss: 0.4092
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8793
# ...loss: 0.4086
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8796
# ...loss: 0.4080
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8797
# ...loss: 0.4073
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8799
# ...loss: 0.4068
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8799
# ...loss: 0.4063
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8802
# ...loss: 0.4057
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8801
# ...loss: 0.4057
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8803
# ...loss: 0.4054
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8804
# ...loss: 0.4054
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8804
# ...loss: 0.4051
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8806
# ...loss: 0.4044
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8808
# ...loss: 0.4040
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8810
# ...loss: 0.4032
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8812
# ...loss: 0.4028
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8812
# ...loss: 0.4026
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8813
# ...loss: 0.4022
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8816
# ...loss: 0.4014
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8817
# ...loss: 0.4011
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8818
# ...loss: 0.4013
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8819
# ...loss: 0.4011
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8820
# ...loss: 0.4005
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8821
# ...loss: 0.4001
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8822
# ...loss: 0.3998
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8823
# ...loss: 0.3998
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8824
# ...loss: 0.3993
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8825
# ...loss: 0.3988
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8826
# ...loss: 0.3984
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8828
# ...loss: 0.3975
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8830
# ...loss: 0.3967
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8831
# ...loss: 0.3964
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8833
# ...loss: 0.3958
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8834
# ...loss: 0.3952
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8836
# ...loss: 0.3948
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8837
# ...loss: 0.3946
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8840
# ...loss: 0.3939
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8840
# ...loss: 0.3935
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8841
# ...loss: 0.3929
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8843
# ...loss: 0.3927
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8844
# ...loss: 0.3924
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8846
# ...loss: 0.3916
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8848
# ...loss: 0.3909
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8850
# ...loss: 0.3903
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8851
# ...loss: 0.3900
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8853
# ...loss: 0.3896
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8854
# ...loss: 0.3895
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8855
# ...loss: 0.3893
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8856
# ...loss: 0.3888
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8858
# ...loss: 0.3880
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8859
# ...loss: 0.3878
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8859
# ...loss: 0.3878
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8859
# ...loss: 0.3876
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8860
# ...loss: 0.3872
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8861
# ...loss: 0.3870
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8861
# ...loss: 0.3868
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8862
# ...loss: 0.3867
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8863
# ...loss: 0.3864
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8863
# ...loss: 0.3864
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8863
# ...loss: 0.3864
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8864
# ...loss: 0.3861
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8866
# ...loss: 0.3855
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8868
# ...loss: 0.3847
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8868
# ...loss: 0.3844
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8869
# ...loss: 0.3839
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8871
# ...loss: 0.3833
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8873
# ...loss: 0.3829
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8874
# ...loss: 0.3823
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8873
# ...loss: 0.3825
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8874
# ...loss: 0.3822
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8874
# ...loss: 0.3821
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8875
# ...loss: 0.3818
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8876
# ...loss: 0.3818
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8877
# ...loss: 0.3812
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8879
# ...loss: 0.3806
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8879
# ...loss: 0.3804
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8880
# ...loss: 0.3799
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8882
# ...loss: 0.3793
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8883
# ...loss: 0.3788
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8883
# ...loss: 0.3786
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8885
# ...loss: 0.3779
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8887
# ...loss: 0.3774
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8888
# ...loss: 0.3768
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8891
# ...loss: 0.3761
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8892
# ...loss: 0.3755
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8892
# ...loss: 0.3756
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8891
# ...loss: 0.3758
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8893
# ...loss: 0.3753
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8894
# ...loss: 0.3750
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8895
# ...loss: 0.3744
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8896
# ...loss: 0.3743
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8894
# ...loss: 0.3747
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8893
# ...loss: 0.3747
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8895
# ...loss: 0.3743
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8896
# ...loss: 0.3743
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8897
# ...loss: 0.3738
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8898
# ...loss: 0.3734
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8900
# ...loss: 0.3728
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8901
# ...loss: 0.3728
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8900
# ...loss: 0.3729
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8901
# ...loss: 0.3729
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8901
# ...loss: 0.3729
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8903
# ...loss: 0.3725
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8904
# ...loss: 0.3722
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8905
# ...loss: 0.3717
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8907
# ...loss: 0.3711
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8908
# ...loss: 0.3705
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8909
# ...loss: 0.3700
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8910
# ...loss: 0.3697
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8911
# ...loss: 0.3692
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8913
# ...loss: 0.3687
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8915
# ...loss: 0.3682
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8916
# ...loss: 0.3679
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8918
# ...loss: 0.3675
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8920
# ...loss: 0.3669
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8920
# ...loss: 0.3667
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8921
# ...loss: 0.3663
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8922
# ...loss: 0.3663
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8922
# ...loss: 0.3662
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8923
# ...loss: 0.3658
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8924
# ...loss: 0.3652
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8926
# ...loss: 0.3646
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8927
# ...loss: 0.3643
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8928
# ...loss: 0.3641
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8927
# ...loss: 0.3641
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8926
# ...loss: 0.3644
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8927
# ...loss: 0.3640
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8928
# ...loss: 0.3637
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8930
# ...loss: 0.3632
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8931
# ...loss: 0.3626
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8933
# ...loss: 0.3621
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8934
# ...loss: 0.3619
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8934
# ...loss: 0.3615
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8936
# ...loss: 0.3610
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8936
# ...loss: 0.3607
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8937
# ...loss: 0.3606
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8938
# ...loss: 0.3603
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8939
# ...loss: 0.3600
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8941
# ...loss: 0.3594
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8942
# ...loss: 0.3590
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8944
# ...loss: 0.3586
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8944
# ...loss: 0.3583
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8945
# ...loss: 0.3578
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8946
# ...loss: 0.3573
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8946
# ...loss: 0.3570
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8946
# ...loss: 0.3569
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8947
# ...loss: 0.3564
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8948
# ...loss: 0.3561
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8949
# ...loss: 0.3557
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8950
# ...loss: 0.3554
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8951
# ...loss: 0.3549
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8953
# ...loss: 0.3544
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8954
# ...loss: 0.3539
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8955
# ...loss: 0.3537
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8956
# ...loss: 0.3533
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8958
# ...loss: 0.3528
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8959
# ...loss: 0.3524
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8960
# ...loss: 0.3520
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8961
# ...loss: 0.3518
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8962
# ...loss: 0.3514
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8963
# ...loss: 0.3513
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8964
# ...loss: 0.3508
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8965
# ...loss: 0.3505
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8966
# ...loss: 0.3500
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8967
# ...loss: 0.3496
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8968
# ...loss: 0.3491
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8969
# ...loss: 0.3489
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8971
# ...loss: 0.3483
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8972
# ...loss: 0.3479
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8973
# ...loss: 0.3475
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8975
# ...loss: 0.3471
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8976
# ...loss: 0.3467
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8977
# ...loss: 0.3465
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8977
# ...loss: 0.3463
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8978
# ...loss: 0.3458
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8980
# ...loss: 0.3453
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8981
# ...loss: 0.3450
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8983
# ...loss: 0.3445
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8984
# ...loss: 0.3439
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8985
# ...loss: 0.3435
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8986
# ...loss: 0.3430
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8987
# ...loss: 0.3426
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8988
# ...loss: 0.3421
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8990
# ...loss: 0.3415
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8991
# ...loss: 0.3414
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8993
# ...loss: 0.3408
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8995
# ...loss: 0.3402
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8996
# ...loss: 0.3396
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8998
# ...loss: 0.3391
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.8999
# ...loss: 0.3388
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9000
# ...loss: 0.3383
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9002
# ...loss: 0.3377
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9004
# ...loss: 0.3372
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9003
# ...loss: 0.3378
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9005
# ...loss: 0.3371
# Results at this batch of epoch 0
# ...sparse_categorical_accuracy: 0.9006
# ...loss: 0.3370
# Results at the end of epoch 0
# ...sparse_categorical_accuracy: 0.9006
# ...loss: 0.3370
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9400
# ...loss: 0.2368
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9400
# ...loss: 0.2122
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.8833
# ...loss: 0.3706
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9025
# ...loss: 0.3200
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9160
# ...loss: 0.2819
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9233
# ...loss: 0.2558
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9286
# ...loss: 0.2366
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9250
# ...loss: 0.2464
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9289
# ...loss: 0.2407
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9330
# ...loss: 0.2300
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9364
# ...loss: 0.2197
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9392
# ...loss: 0.2093
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9369
# ...loss: 0.2078
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9393
# ...loss: 0.1991
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9407
# ...loss: 0.1981
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9400
# ...loss: 0.2046
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9394
# ...loss: 0.2065
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9378
# ...loss: 0.2128
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9368
# ...loss: 0.2124
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9370
# ...loss: 0.2103
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9367
# ...loss: 0.2091
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9377
# ...loss: 0.2038
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9365
# ...loss: 0.2039
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9367
# ...loss: 0.2049
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9372
# ...loss: 0.2032
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9358
# ...loss: 0.2108
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9337
# ...loss: 0.2194
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9346
# ...loss: 0.2192
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9355
# ...loss: 0.2164
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9360
# ...loss: 0.2152
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9352
# ...loss: 0.2176
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9337
# ...loss: 0.2197
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9352
# ...loss: 0.2164
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9353
# ...loss: 0.2145
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9360
# ...loss: 0.2126
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9361
# ...loss: 0.2111
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9365
# ...loss: 0.2114
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9366
# ...loss: 0.2123
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9367
# ...loss: 0.2112
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9362
# ...loss: 0.2129
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9361
# ...loss: 0.2120
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9362
# ...loss: 0.2110
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9360
# ...loss: 0.2106
# Results at this batch of epoch 1
# ...sparse_categorical_accuracy: 0.9348
# ...loss: 0.2134
# Results at this batch of epoch 1
# ...
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1323
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1321
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1323
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1321
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1312
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1312
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1312
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1312
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1309
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1308
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1312
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1325
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1325
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1328
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9598
# ...loss: 0.1333
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9598
# ...loss: 0.1335
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9598
# ...loss: 0.1334
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9599
# ...loss: 0.1333
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9599
# ...loss: 0.1332
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1330
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1327
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1325
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1327
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.1325
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1325
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1323
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1323
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1323
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1321
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1321
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9601
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1324
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1322
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9602
# ...loss: 0.1321
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1320
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1319
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1318
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9603
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1317
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1315
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1316
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1314
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1313
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9604
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1311
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1310
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1308
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1307
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1308
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9605
# ...loss: 0.1308
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1307
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1307
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1306
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1306
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1305
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9606
# ...loss: 0.1305
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1303
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1303
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1301
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9607
# ...loss: 0.1300
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1299
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1300
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9608
# ...loss: 0.1298
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9609
# ...loss: 0.1297
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9609
# ...loss: 0.1296
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9610
# ...loss: 0.1295
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9611
# ...loss: 0.1292
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9611
# ...loss: 0.1291
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9611
# ...loss: 0.1290
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1289
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1287
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1288
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1286
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1285
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9612
# ...loss: 0.1284
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9613
# ...loss: 0.1282
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9614
# ...loss: 0.1280
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9615
# ...loss: 0.1278
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9615
# ...loss: 0.1276
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9615
# ...loss: 0.1277
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9616
# ...loss: 0.1274
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9617
# ...loss: 0.1272
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9618
# ...loss: 0.1269
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9618
# ...loss: 0.1268
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9618
# ...loss: 0.1268
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9618
# ...loss: 0.1266
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9619
# ...loss: 0.1264
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9619
# ...loss: 0.1262
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9618
# ...loss: 0.1270
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9619
# ...loss: 0.1267
# Results at this batch of epoch 2
# ...sparse_categorical_accuracy: 0.9619
# ...loss: 0.1269
# Results at the end of epoch 2
# ...sparse_categorical_accuracy: 0.9619
# ...loss: 0.1269

# %%
@tf.function
def test_step(inputs, targets):
    predictions = model(inputs, training=False)
    loss = loss_fn(targets, predictions)

    logs = {}
    for metric in metrics:
        metric.update_state(targets, predictions)
        logs["val_" + metric.name] = metric.result()

    loss_tracking_metric.update_state(loss)
    logs["val_loss"] = loss_tracking_metric.result()
    return logs

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32)
reset_metrics()
for inputs_batch, targets_batch in val_dataset:
    logs = test_step(inputs_batch, targets_batch)
print("Evaluation results:")
for key, value in logs.items():
    print(f"...{key}: {value:.4f}")
# Out:
# Evaluation results:
# ...val_sparse_categorical_accuracy: 0.9680
# ...val_loss: 0.1148

# %%
loss_fn = keras.losses.SparseCategoricalCrossentropy()
loss_tracker = keras.metrics.Mean(name="loss")

class CustomModel(keras.Model):
    def train_step(self, data):
        inputs, targets = data
        with tf.GradientTape() as tape:
            predictions = self(inputs, training=True)
            loss = loss_fn(targets, predictions)
        gradients = tape.gradient(loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))

        loss_tracker.update_state(loss)
        return {"loss": loss_tracker.result()}

    @property
    def metrics(self):
        return [loss_tracker]

# %%
inputs = keras.Input(shape=(28 * 28,))
features = layers.Dense(512, activation="relu")(inputs)
features = layers.Dropout(0.5)(features)
outputs = layers.Dense(10, activation="softmax")(features)
model = CustomModel(inputs, outputs)

model.compile(optimizer=keras.optimizers.RMSprop())
model.fit(train_images, train_labels, epochs=3)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.4514
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1698
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1312

# %%
class CustomModel(keras.Model):
    def train_step(self, data):
        inputs, targets = data
        with tf.GradientTape() as tape:
            predictions = self(inputs, training=True)
            loss = self.compiled_loss(targets, predictions)
        gradients = tape.gradient(loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))
        self.compiled_metrics.update_state(targets, predictions)
        return {m.name: m.result() for m in self.metrics}

# %%
inputs = keras.Input(shape=(28 * 28,))
features = layers.Dense(512, activation="relu")(inputs)
features = layers.Dropout(0.5)(features)
outputs = layers.Dense(10, activation="softmax")(features)
model = CustomModel(inputs, outputs)

model.compile(optimizer=keras.optimizers.RMSprop(),
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])
model.fit(train_images, train_labels, epochs=3)
# Out:
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:667: UserWarning: `model.compiled_loss()` is deprecated. Instead, use `model.compute_loss(x, y, y_pred, sample_weight, training)`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:642: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - sparse_categorical_accuracy: 0.8629 - loss: 0.1000
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - sparse_categorical_accuracy: 0.9505 - loss: 0.1000
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - sparse_categorical_accuracy: 0.9614 - loss: 0.1000

# %% [markdown]
# ---

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pooling = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 208,406 (814.09 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 104,204 (407.05 KB)

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, strides = 2, activation="relu")(inputs)
x = layers.Conv2D(filters=64, strides = 2, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, strides = 2, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_stride_2 = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_stride_2.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)     │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 13, 13, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 6, 6, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 2, 2, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 195,606 (764.09 KB)
#  Trainable params: 97,802 (382.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 97,804 (382.05 KB)

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model_stride_2.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model_stride_2.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8729 - loss: 0.4332
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9776 - loss: 0.0720
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9863 - loss: 0.0453
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9907 - loss: 0.0331
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9921 - loss: 0.0254

# %%
test_loss, test_acc = model_stride_2.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9823 - loss: 0.0616
# Test accuracy: 0.986

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_18 (InputLayer)     │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 22, 22, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 61952)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 10)             │       619,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 712,202 (2.72 MB)
#  Trainable params: 712,202 (2.72 MB)
#  Non-trainable params: 0 (0.00 B)
